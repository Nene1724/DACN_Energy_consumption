# %% [markdown]
# # Energy Prediction Training Notebook
#
# Notebook này train lại mô hình dự đoán năng lượng tiêu thụ theo **2 dataset thực tế**:
# - `ml-controller/data/360_models_benchmark_jetson.csv`
# - `ml-controller/data/253_models_benchmark_rpi5.csv`
#
# Mục tiêu:
# - train **riêng theo thiết bị** để tăng độ chính xác thực tế,
# - xuất artifact tương thích ngay với `ml-controller/python/energy_predictor_service.py`,
# - giữ pipeline gọn, tái lập được, và ít phụ thuộc thư viện ngoài `scikit-learn`.

# %%
import json
import pickle
import random
import warnings
from datetime import datetime, timezone
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import randint
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, HistGradientBoostingRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, make_scorer, r2_score
from sklearn.model_selection import KFold, StratifiedKFold, RandomizedSearchCV, cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler, KBinsDiscretizer

warnings.filterwarnings('ignore')
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

sns.set_theme(style='whitegrid', context='talk')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['figure.dpi'] = 120

print(f'SEED = {SEED}')
# Out:
# SEED = 42

# %%
def resolve_notebook_dir() -> Path:
    cwd = Path.cwd().resolve()
    if (cwd / 'energy_prediction_model.ipynb').exists():
        return cwd
    candidate = cwd / 'ml-controller' / 'notebooks'
    if (candidate / 'energy_prediction_model.ipynb').exists():
        return candidate
    raise FileNotFoundError('Không xác định được thư mục notebook.')

NOTEBOOK_DIR = resolve_notebook_dir()
PROJECT_ROOT = NOTEBOOK_DIR.parent
DATA_DIR = PROJECT_ROOT / 'data'
ARTIFACTS_DIR = PROJECT_ROOT / 'artifacts'
FIGURES_DIR = ARTIFACTS_DIR / 'report_figures'
ARTIFACTS_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

JETSON_CSV = DATA_DIR / '360_models_benchmark_jetson.csv'
RPI5_CSV = DATA_DIR / '253_models_benchmark_rpi5.csv'


def save_figure(name: str):
    path = FIGURES_DIR / name
    plt.tight_layout()
    plt.savefig(path, dpi=220, bbox_inches='tight')
    print(f'Đã lưu hình: {path}')
    return path


print('NOTEBOOK_DIR =', NOTEBOOK_DIR)
print('PROJECT_ROOT =', PROJECT_ROOT)
print('JETSON_CSV exists =', JETSON_CSV.exists())
print('RPI5_CSV exists =', RPI5_CSV.exists())
print('FIGURES_DIR =', FIGURES_DIR)
# Out:
# NOTEBOOK_DIR = D:\KLTN\DACN_Energy_consumption\ml-controller\notebooks
# PROJECT_ROOT = D:\KLTN\DACN_Energy_consumption\ml-controller
# JETSON_CSV exists = True
# RPI5_CSV exists = True
# FIGURES_DIR = D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures

# %% [markdown]
# ## Chuẩn bị dữ liệu và đặc trưng
#
# Thiết kế feature giữ tương thích với `EnergyPredictorService` hiện tại.
#
# Điểm quan trọng cho Jetson:
# - thêm `batch_high_power`,
# - suy luận từ `energy_avg_mwh / latency_avg_s`,
# - dùng ngưỡng `10.0 mWh/s` vì benchmark trên repo cho thấy đây là mốc tách 2 power profile tốt nhất.

# %%
BASE_FEATURES = [
    'params_m', 'gflops', 'gmacs', 'size_mb', 'latency_avg_s', 'throughput_iter_per_s'
]

FEATURE_COLUMNS = BASE_FEATURES + [
    'gflops_per_param',
    'gmacs_per_mb',
    'latency_throughput_ratio',
    'compute_intensity',
    'model_complexity',
    'computational_density',
    'log_params_m',
    'log_gflops',
    'log_size_mb',
    'log_gmacs',
    'log_latency',
    'log_throughput',
    'log_model_complexity',
    'log_compute_intensity',
    'log_params_x_log_latency',
    'log_gflops_x_log_latency',
    'batch_high_power',
]

JETSON_BATCH_THRESHOLD = 10.0


FAMILY_PATTERNS = [
    'convnextv2', 'efficientformer', 'efficientvit', 'mobilenet', 'efficientnet',
    'convnext', 'coatnet', 'shufflenet', 'squeezenet', 'ghostnet', 'mnasnet',
    'densenet', 'regnet', 'resnet', 'seresnet', 'deit', 'beit', 'crossvit',
    'convit', 'maxvit', 'fastvit', 'mobilevit', 'edgenext', 'coat', 'cait',
    'xcit', 'swin', 'vit', 'vgg', 'inception', 'rexnet', 'fbnetv', 'lcnet',
    'tinynet', 'hrnet', 'darknet', 'dla', 'dpn',
]


def infer_family(model_name: str) -> str:
    model_name = str(model_name).lower()
    for pattern in FAMILY_PATTERNS:
        if pattern in model_name:
            return pattern
    prefix = ''.join(ch for ch in model_name.split('_')[0] if ch.isalpha())
    return prefix or 'other'


def smape(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    denom = np.abs(y_true) + np.abs(y_pred) + 1e-9
    return float(np.mean(2.0 * np.abs(y_pred - y_true) / denom) * 100.0)


def mape_eps(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    denom = np.maximum(np.abs(y_true), eps)
    return float(np.mean(np.abs((y_true - y_pred) / denom)) * 100.0)


def regression_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    return {
        'mae': float(mean_absolute_error(y_true, y_pred)),
        'rmse': float(np.sqrt(mean_squared_error(y_true, y_pred))),
        'smape': float(smape(y_true, y_pred)),
        'mape_eps': float(mape_eps(y_true, y_pred)),
        'r2_original': float(r2_score(y_true, y_pred)),
        'r2_log': float(r2_score(np.log1p(y_true), np.log1p(np.clip(y_pred, 0, None)))),
        'median_abs_error': float(np.median(np.abs(y_true - y_pred))),
    }


def add_device_features(df: pd.DataFrame, device_key: str) -> pd.DataFrame:
    df = df.copy()
    df['device'] = device_key
    df['gflops_per_param'] = df['gflops'] / (df['params_m'] + 1e-6)
    df['gmacs_per_mb'] = df['gmacs'] / (df['size_mb'] + 1e-6)
    df['latency_throughput_ratio'] = df['latency_avg_s'] * df['throughput_iter_per_s']
    df['compute_intensity'] = df['gflops'] * df['latency_avg_s']
    df['model_complexity'] = df['params_m'] * df['gflops']
    df['computational_density'] = df['gflops'] / (df['size_mb'] + 1e-6)
    df['log_params_m'] = np.log1p(df['params_m'])
    df['log_gflops'] = np.log1p(df['gflops'])
    df['log_size_mb'] = np.log1p(df['size_mb'])
    df['log_gmacs'] = np.log1p(df['gmacs'])
    df['log_latency'] = np.log1p(df['latency_avg_s'])
    df['log_throughput'] = np.log1p(df['throughput_iter_per_s'])
    df['log_model_complexity'] = np.log1p(df['model_complexity'])
    df['log_compute_intensity'] = np.log1p(df['compute_intensity'])
    df['log_params_x_log_latency'] = df['log_params_m'] * df['log_latency']
    df['log_gflops_x_log_latency'] = df['log_gflops'] * df['log_latency']

    if 'jetson' in device_key:
        power_ratio = df['energy_avg_mwh'] / (df['latency_avg_s'] + 1e-9)
        df['batch_high_power'] = (power_ratio > JETSON_BATCH_THRESHOLD).astype(int)
    else:
        df['batch_high_power'] = 0

    return df


def load_device_dataset(csv_path: Path, device_key: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)
    required = BASE_FEATURES + ['energy_avg_mwh']
    missing = [col for col in required if col not in df.columns]
    if missing:
        raise ValueError(f'{csv_path.name} thiếu cột bắt buộc: {missing}')

    numeric_cols = required.copy()
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    df = df.dropna(subset=numeric_cols).copy()
    df = add_device_features(df, device_key)
    df['family'] = df['model'].map(infer_family)
    return df


jetson_df = load_device_dataset(JETSON_CSV, 'jetson_nano')
rpi5_df = load_device_dataset(RPI5_CSV, 'raspberry_pi5')
combined_df = pd.concat([jetson_df, rpi5_df], ignore_index=True)

print('Jetson shape =', jetson_df.shape)
print('RPi5 shape   =', rpi5_df.shape)
print('Combined     =', combined_df.shape)
print('FEATURE_COLUMNS =', len(FEATURE_COLUMNS))
print('Jetson batch_high_power counts =')
print(jetson_df['batch_high_power'].value_counts().sort_index())
print('Top family counts (combined) =')
print(combined_df['family'].value_counts().head(12))
# Out:
# Jetson shape = (360, 35)
# RPi5 shape   = (253, 38)
# Combined     = (613, 38)
# FEATURE_COLUMNS = 23
# Jetson batch_high_power counts =
# batch_high_power
# 0    122
# 1    238
# Name: count, dtype: int64
# Top family counts (combined) =
# family
# resnet          94
# efficientnet    92
# regnet          74
# mobilenet       53
# vit             50
# xcit            30
# convnext        18
# vgg             18
# deit            17
# mnasnet         14
# edgenext        13
# densenet        12
# Name: count, dtype: int64

# %% [markdown]
# ## Trực quan hóa dữ liệu đầu vào
#
# Các biểu đồ dưới đây giúp mô tả dataset và cơ sở hình thành pipeline train trong báo cáo:
# - quy mô dữ liệu theo từng thiết bị,
# - phân phối năng lượng tiêu thụ,
# - quan hệ giữa độ phức tạp mô hình và năng lượng,
# - dấu hiệu tồn tại hai power profile trên Jetson Nano.

# %%
device_summary = pd.DataFrame([
    {
        'device': 'Jetson Nano',
        'samples': len(jetson_df),
        'energy_mean': jetson_df['energy_avg_mwh'].mean(),
        'energy_median': jetson_df['energy_avg_mwh'].median(),
    },
    {
        'device': 'Raspberry Pi 5',
        'samples': len(rpi5_df),
        'energy_mean': rpi5_df['energy_avg_mwh'].mean(),
        'energy_median': rpi5_df['energy_avg_mwh'].median(),
    },
])

fig, axes = plt.subplots(1, 3, figsize=(20, 5.5))

sns.barplot(data=device_summary, x='device', y='samples', palette=['#1f77b4', '#d62728'], ax=axes[0])
axes[0].set_title('Số lượng mẫu benchmark theo thiết bị')
axes[0].set_xlabel('')
axes[0].set_ylabel('Số mẫu')

sns.boxplot(data=combined_df, x='device', y='energy_avg_mwh', palette=['#1f77b4', '#d62728'], ax=axes[1])
axes[1].set_title('Phân phối năng lượng tiêu thụ theo thiết bị')
axes[1].set_xlabel('Thiết bị')
axes[1].set_ylabel('Năng lượng (mWh)')
axes[1].set_yscale('log')
axes[1].tick_params(axis='x', rotation=10)

sns.scatterplot(
    data=combined_df,
    x='gflops',
    y='energy_avg_mwh',
    hue='device',
    palette=['#1f77b4', '#d62728'],
    alpha=0.75,
    s=70,
    ax=axes[2],
)
axes[2].set_title('GFLOPs và năng lượng tiêu thụ')
axes[2].set_xlabel('GFLOPs')
axes[2].set_ylabel('Năng lượng (mWh)')
axes[2].set_xscale('log')
axes[2].set_yscale('log')

save_figure('01_dataset_overview.png')
plt.show()

jetson_ratio = jetson_df['energy_avg_mwh'] / (jetson_df['latency_avg_s'] + 1e-9)
jetson_plot_df = jetson_df.copy()
jetson_plot_df['energy_per_latency'] = jetson_ratio
jetson_plot_df['batch_label'] = jetson_plot_df['batch_high_power'].map({0: 'Low power profile', 1: 'High power profile'})

fig, axes = plt.subplots(1, 2, figsize=(18, 6))

sns.scatterplot(
    data=jetson_plot_df,
    x='latency_avg_s',
    y='energy_avg_mwh',
    hue='batch_label',
    palette=['#2ca02c', '#ff7f0e'],
    alpha=0.8,
    s=70,
    ax=axes[0],
)
axes[0].set_title('Jetson Nano: Energy vs Latency theo power profile')
axes[0].set_xlabel('Latency trung bình (s)')
axes[0].set_ylabel('Năng lượng (mWh)')
axes[0].set_xscale('log')
axes[0].set_yscale('log')

sns.histplot(jetson_plot_df['energy_per_latency'], bins=35, color='#1f77b4', edgecolor='white', ax=axes[1])
axes[1].axvline(JETSON_BATCH_THRESHOLD, color='red', linestyle='--', linewidth=2, label=f'Threshold = {JETSON_BATCH_THRESHOLD:.1f} mWh/s')
axes[1].set_title('Jetson Nano: Phân phối energy/latency ratio')
axes[1].set_xlabel('Energy / Latency (mWh/s)')
axes[1].set_ylabel('Số lượng mẫu')
axes[1].legend()

save_figure('02_jetson_power_profiles.png')
plt.show()
# Out:
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\01_dataset_overview.png
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\02_jetson_power_profiles.png

# %% [markdown]
# ## Trực quan hóa phân loại dataset theo family
#
# Phần này dùng để mô tả cấu trúc dataset theo họ kiến trúc mô hình (`family`), rất phù hợp cho chương phân tích dữ liệu trong báo cáo.
#
# `family` được suy ra từ tiền tố/tên kiến trúc bên trong cột `model`, ví dụ: `resnet`, `efficientnet`, `mobilenet`, `vit`, `regnet`, `convnext`...

# %%
family_counts = (
    combined_df.groupby(['family', 'device'])
    .size()
    .reset_index(name='count')
)

top_families = combined_df['family'].value_counts().head(12).index.tolist()
family_counts_top = family_counts[family_counts['family'].isin(top_families)].copy()
family_energy_top = combined_df[combined_df['family'].isin(top_families)].copy()

device_map = {
    'jetson_nano': 'Jetson Nano',
    'raspberry_pi5': 'Raspberry Pi 5',
}
family_counts_top['device_label'] = family_counts_top['device'].map(device_map).fillna(family_counts_top['device'])
family_energy_top['device_label'] = family_energy_top['device'].map(device_map).fillna(family_energy_top['device'])

fig, axes = plt.subplots(1, 2, figsize=(22, 7))

sns.barplot(
    data=family_counts_top,
    x='family',
    y='count',
    hue='device_label',
    palette=['#1f77b4', '#d62728'],
    ax=axes[0],
)
axes[0].set_xlabel('Family')
axes[0].set_ylabel('Sample count')
axes[0].tick_params(axis='x', rotation=45)
axes[0].legend(title='Device', frameon=False)

family_total = (
    combined_df['family']
    .value_counts()
    .head(12)
    .rename_axis('family')
    .reset_index(name='count')
)
sns.barplot(data=family_total, x='family', y='count', color='#4c78a8', ax=axes[1])
axes[1].set_xlabel('Family')
axes[1].set_ylabel('Total samples')
axes[1].tick_params(axis='x', rotation=45)

for ax in axes:
    sns.despine(ax=ax, top=True, right=True)

save_figure('08_family_distribution.png')
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(22, 8))

median_order = (
    family_energy_top.groupby('family')['energy_avg_mwh']
    .median()
    .sort_values()
    .index
)

sns.boxplot(
    data=family_energy_top,
    x='family',
    y='energy_avg_mwh',
    order=median_order,
    color='#72b7b2',
    ax=axes[0],
)
axes[0].set_xlabel('Family')
axes[0].set_ylabel('Energy (mWh)')
axes[0].set_yscale('log')
axes[0].tick_params(axis='x', rotation=45)

scatter_families = combined_df['family'].value_counts().head(8).index.tolist()
scatter_df = combined_df.copy()
scatter_df['family_grouped'] = scatter_df['family'].where(scatter_df['family'].isin(scatter_families), 'Other')
scatter_df['device_label'] = scatter_df['device'].map(device_map).fillna(scatter_df['device'])

sns.scatterplot(
    data=scatter_df,
    x='gflops',
    y='energy_avg_mwh',
    hue='family_grouped',
    style='device_label',
    alpha=0.4,
    s=60,
    ax=axes[1],
)
axes[1].set_xlabel('GFLOPs')
axes[1].set_ylabel('Energy (mWh)')
axes[1].set_xscale('log')
axes[1].set_yscale('log')
legend = axes[1].legend(loc='center left', bbox_to_anchor=(1.02, 0.5))
legend.set_title('Family / Device')

for ax in axes:
    sns.despine(ax=ax, top=True, right=True)

save_figure('09_family_energy_patterns.png')
plt.show()
# Out:
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\08_family_distribution.png
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\09_family_energy_patterns.png

# %% [markdown]
# ## Benchmark nhanh các họ mô hình
#
# Phần này chỉ để xác nhận lại hướng chọn mô hình với dữ liệu hiện tại.
# Sau benchmark, notebook sẽ chỉ fine-tune `ExtraTrees`, vì đây là mô hình thắng cuộc rõ rệt trên cả 2 thiết bị khi dùng log-transform target.

# %%
def build_ttr_pipeline(regressor):
    return Pipeline([
        ('scaler', RobustScaler()),
        ('model', TransformedTargetRegressor(
            regressor=regressor,
            func=np.log1p,
            inverse_func=np.expm1,
        ))
    ])


BASELINE_CANDIDATES = {
    'ExtraTrees': lambda: build_ttr_pipeline(
        ExtraTreesRegressor(
            n_estimators=800,
            max_features=0.8,
            min_samples_split=2,
            min_samples_leaf=1,
            random_state=SEED,
            n_jobs=-1,
        )
    ),
    'RandomForest': lambda: build_ttr_pipeline(
        RandomForestRegressor(
            n_estimators=700,
            max_features='sqrt',
            min_samples_split=2,
            min_samples_leaf=1,
            random_state=SEED,
            n_jobs=-1,
        )
    ),
    'HistGradientBoosting': lambda: build_ttr_pipeline(
        HistGradientBoostingRegressor(
            learning_rate=0.05,
            max_depth=6,
            max_iter=500,
            min_samples_leaf=8,
            l2_regularization=0.05,
            random_state=SEED,
        )
    ),
    'GradientBoosting': lambda: build_ttr_pipeline(
        GradientBoostingRegressor(
            learning_rate=0.03,
            n_estimators=700,
            max_depth=3,
            subsample=0.85,
            random_state=SEED,
        )
    ),
    'Ridge': lambda: build_ttr_pipeline(Ridge(alpha=1.0)),
}


def make_cv(df: pd.DataFrame, device_key: str):
    y = df['energy_avg_mwh'].values
    if 'jetson' in device_key:
        bins = KBinsDiscretizer(
            n_bins=10,
            encode='ordinal',
            strategy='quantile',
            subsample=None,
            quantile_method='averaged_inverted_cdf',
        ).fit_transform(y.reshape(-1, 1)).ravel().astype(int)
        return list(StratifiedKFold(n_splits=10, shuffle=True, random_state=SEED).split(df[FEATURE_COLUMNS], bins))
    return KFold(n_splits=5, shuffle=True, random_state=SEED)


def benchmark_candidates(df: pd.DataFrame, device_key: str) -> pd.DataFrame:
    X = df[FEATURE_COLUMNS]
    y = df['energy_avg_mwh'].values
    cv = make_cv(df, device_key)
    rows = []
    for name, builder in BASELINE_CANDIDATES.items():
        model = builder()
        pred = cross_val_predict(model, X, y, cv=cv, n_jobs=1)
        metrics = regression_metrics(y, pred)
        rows.append({
            'model': name,
            'smape': metrics['smape'],
            'mape_eps': metrics['mape_eps'],
            'r2_log': metrics['r2_log'],
            'r2_original': metrics['r2_original'],
            'median_abs_error': metrics['median_abs_error'],
        })
    return pd.DataFrame(rows).sort_values(['smape', 'median_abs_error']).reset_index(drop=True)


jetson_baseline = benchmark_candidates(jetson_df, 'jetson_nano')
rpi5_baseline = benchmark_candidates(rpi5_df, 'raspberry_pi5')

print('JETSON BASELINE')
print(jetson_baseline.to_string(index=False))
print()
print('RPI5 BASELINE')
print(rpi5_baseline.to_string(index=False))
# Out:
# JETSON BASELINE
#                model     smape  mape_eps   r2_log  r2_original  median_abs_error
#           ExtraTrees 20.567149 21.531026 0.937792     0.600582          5.434236
#                Ridge 26.189565 29.542597 0.943248     0.603920         12.547116
#     GradientBoosting 27.359826 29.000977 0.918997     0.513580         10.531394
# HistGradientBoosting 28.049794 31.676075 0.897690     0.481380         10.917095
#         RandomForest 29.510444 32.339528 0.884681     0.319826          9.741480
#
# RPI5 BASELINE
#                model     smape  mape_eps   r2_log  r2_original  median_abs_error
#           ExtraTrees 13.191246 13.489436 0.954361     0.895809          2.836138
#         RandomForest 13.688170 13.964607 0.949174     0.862855          2.862799
#     GradientBoosting 14.342420 14.639729 0.946851     0.895077          3.138167
#                Ridge 14.713390 15.340533 0.945866     0.848262          3.385616
# ...

# %% [markdown]
# ## Trực quan hóa benchmark mô hình nền
#
# Phần này giúp giải thích vì sao notebook chọn `ExtraTrees` làm họ mô hình chính trước khi fine-tune.

# %%
baseline_compare = pd.concat([
    jetson_baseline.assign(device='Jetson Nano'),
    rpi5_baseline.assign(device='Raspberry Pi 5'),
], ignore_index=True)

fig, axes = plt.subplots(1, 2, figsize=(20, 6))

sns.barplot(data=baseline_compare, x='model', y='smape', hue='device', ax=axes[0])
axes[0].set_title('So sánh baseline theo SMAPE')
axes[0].set_xlabel('Mô hình')
axes[0].set_ylabel('SMAPE (%)')
axes[0].tick_params(axis='x', rotation=20)

sns.barplot(data=baseline_compare, x='model', y='r2_log', hue='device', ax=axes[1])
axes[1].set_title('So sánh baseline theo R² trên log-scale')
axes[1].set_xlabel('Mô hình')
axes[1].set_ylabel('R² log-scale')
axes[1].tick_params(axis='x', rotation=20)

save_figure('03_baseline_model_comparison.png')
plt.show()
# Out:
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\03_baseline_model_comparison.png

# %% [markdown]
# ## Fine-tune riêng theo thiết bị
#
# Chiến lược chốt cho production:
# - **Jetson**: tối ưu theo `RMSE/log-scale` ổn định hơn trên phân phối rất lệch.
# - **RPi5**: tối ưu theo **SMAPE** vì dữ liệu gọn hơn và metric này phản ánh sai số tương đối trực quan hơn.

# %%
def tune_jetson_model(df: pd.DataFrame):
    X = df[FEATURE_COLUMNS]
    y = df['energy_avg_mwh'].values
    bins = KBinsDiscretizer(
        n_bins=10,
        encode='ordinal',
        strategy='quantile',
        subsample=None,
        quantile_method='averaged_inverted_cdf',
    ).fit_transform(y.reshape(-1, 1)).ravel().astype(int)
    cv = list(StratifiedKFold(n_splits=10, shuffle=True, random_state=SEED).split(X, bins))

    pipeline = build_ttr_pipeline(
        ExtraTreesRegressor(random_state=SEED, n_jobs=-1)
    )
    param_dist = {
        'model__regressor__n_estimators': randint(800, 1401),
        'model__regressor__max_depth': [12, 16, 20, 24, 28, None],
        'model__regressor__min_samples_split': randint(2, 6),
        'model__regressor__min_samples_leaf': randint(1, 3),
        'model__regressor__max_features': [0.7, 0.8, 0.9, 1.0],
        'model__regressor__bootstrap': [False],
    }

    search = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=param_dist,
        n_iter=35,
        scoring='neg_root_mean_squared_error',
        cv=cv,
        random_state=SEED,
        n_jobs=-1,
        verbose=0,
    )
    search.fit(X, y)
    pred = cross_val_predict(search.best_estimator_, X, y, cv=cv, n_jobs=1)
    metrics = regression_metrics(y, pred)
    return {
        'device_key': 'jetson_nano',
        'best_estimator': search.best_estimator_.fit(X, y),
        'best_params': search.best_params_,
        'cv_metrics': metrics,
        'cv_predictions': pred,
        'samples': int(len(df)),
        'cv_strategy': 'StratifiedKFold(n_splits=10)',
    }


SMAPE_SCORER = make_scorer(smape, greater_is_better=False)


def tune_rpi5_model(df: pd.DataFrame):
    X = df[FEATURE_COLUMNS]
    y = df['energy_avg_mwh'].values
    cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

    pipeline = build_ttr_pipeline(
        ExtraTreesRegressor(random_state=SEED, n_jobs=-1)
    )
    param_dist = {
        'model__regressor__n_estimators': randint(900, 1501),
        'model__regressor__max_depth': [8, 10, 12, 14, 16, 18],
        'model__regressor__min_samples_split': randint(2, 5),
        'model__regressor__min_samples_leaf': randint(1, 3),
        'model__regressor__max_features': [0.6, 0.7, 0.8, 0.9],
        'model__regressor__bootstrap': [False],
    }

    search = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=param_dist,
        n_iter=25,
        scoring=SMAPE_SCORER,
        cv=cv,
        random_state=SEED,
        n_jobs=-1,
        verbose=0,
    )
    search.fit(X, y)
    pred = cross_val_predict(search.best_estimator_, X, y, cv=cv, n_jobs=1)
    metrics = regression_metrics(y, pred)
    return {
        'device_key': 'raspberry_pi5',
        'best_estimator': search.best_estimator_.fit(X, y),
        'best_params': search.best_params_,
        'cv_metrics': metrics,
        'cv_predictions': pred,
        'samples': int(len(df)),
        'cv_strategy': 'KFold(n_splits=5)',
    }


jetson_result = tune_jetson_model(jetson_df)
rpi5_result = tune_rpi5_model(rpi5_df)

print('JETSON BEST PARAMS')
print(jetson_result['best_params'])
print(json.dumps(jetson_result['cv_metrics'], indent=2, ensure_ascii=False))
print()
print('RPI5 BEST PARAMS')
print(rpi5_result['best_params'])
print(json.dumps(rpi5_result['cv_metrics'], indent=2, ensure_ascii=False))
# Out:
# JETSON BEST PARAMS
# {'model__regressor__bootstrap': False, 'model__regressor__max_depth': 28, 'model__regressor__max_features': 1.0, 'model__regressor__min_samples_leaf': 1, 'model__regressor__min_samples_split': 3, 'model__regressor__n_estimators': 852}
# {
#   "mae": 101.3980050765216,
#   "rmse": 550.3426237890056,
#   "smape": 20.162174854870557,
#   "mape_eps": 21.07900438055829,
#   "r2_original": 0.6148207610533192,
#   "r2_log": 0.9402131459830397,
#   "median_abs_error": 5.904591933326586
# }
#
# RPI5 BEST PARAMS
# {'model__regressor__bootstrap': False, 'model__regressor__max_depth': 14, 'model__regressor__max_features': 0.6, 'model__regressor__min_samples_leaf': 1, 'model__regressor__min_samples_split': 4, 'model__regressor__n_estimators': 971}
# {
#   "mae": 5.155334557172807,
#   "rmse": 12.075813080749729,
#   "smape": 12.781385187961241,
#   "mape_eps": 12.985576543849806,
#   "r2_original": 0.8895876356747618,
#   "r2_log": 0.9571445116452824,
# ...

# %% [markdown]
# ## Trực quan hóa chất lượng mô hình sau fine-tune
#
# Nhóm biểu đồ này phù hợp để đưa vào phần đánh giá mô hình trong báo cáo:
# - Actual vs Predicted,
# - phân phối residuals,
# - mức quan trọng của từng đặc trưng đầu vào.

# %%
jetson_diag = pd.DataFrame({
    'actual': jetson_df['energy_avg_mwh'].values,
    'predicted': jetson_result['cv_predictions'],
})
jetson_diag['residual'] = jetson_diag['predicted'] - jetson_diag['actual']

rpi5_diag = pd.DataFrame({
    'actual': rpi5_df['energy_avg_mwh'].values,
    'predicted': rpi5_result['cv_predictions'],
})
rpi5_diag['residual'] = rpi5_diag['predicted'] - rpi5_diag['actual']

fig, axes = plt.subplots(1, 2, figsize=(18, 7))
for ax, diag_df, title, color in [
    (axes[0], jetson_diag, 'Jetson Nano', '#1f77b4'),
    (axes[1], rpi5_diag, 'Raspberry Pi 5', '#d62728'),
]:
    sns.scatterplot(data=diag_df, x='actual', y='predicted', alpha=0.75, s=70, color=color, ax=ax)
    low = min(diag_df['actual'].min(), diag_df['predicted'].min())
    high = max(diag_df['actual'].max(), diag_df['predicted'].max())
    ax.plot([low, high], [low, high], linestyle='--', color='black', linewidth=1.5)
    ax.set_title(f'Actual vs Predicted - {title}')
    ax.set_xlabel('Giá trị thực (mWh)')
    ax.set_ylabel('Giá trị dự đoán (mWh)')
    ax.set_xscale('log')
    ax.set_yscale('log')

save_figure('04_actual_vs_predicted.png')
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(18, 6))
sns.histplot(jetson_diag['residual'], bins=30, kde=True, color='#1f77b4', ax=axes[0])
axes[0].axvline(0, color='black', linestyle='--', linewidth=1.5)
axes[0].set_title('Residual distribution - Jetson Nano')
axes[0].set_xlabel('Residual (predicted - actual)')

sns.histplot(rpi5_diag['residual'], bins=30, kde=True, color='#d62728', ax=axes[1])
axes[1].axvline(0, color='black', linestyle='--', linewidth=1.5)
axes[1].set_title('Residual distribution - Raspberry Pi 5')
axes[1].set_xlabel('Residual (predicted - actual)')

save_figure('05_residual_distributions.png')
plt.show()


def extract_feature_importance(fitted_pipeline):
    regressor = fitted_pipeline.named_steps['model'].regressor_
    return pd.DataFrame({
        'feature': FEATURE_COLUMNS,
        'importance': regressor.feature_importances_,
    }).sort_values('importance', ascending=False)

jetson_importance = extract_feature_importance(jetson_result['best_estimator']).head(12)
rpi5_importance = extract_feature_importance(rpi5_result['best_estimator']).head(12)

fig, axes = plt.subplots(1, 2, figsize=(20, 7))
sns.barplot(data=jetson_importance, x='importance', y='feature', color='#1f77b4', ax=axes[0])
axes[0].set_title('Top 12 feature importance - Jetson Nano')
axes[0].set_xlabel('Importance')
axes[0].set_ylabel('Feature')

sns.barplot(data=rpi5_importance, x='importance', y='feature', color='#d62728', ax=axes[1])
axes[1].set_title('Top 12 feature importance - Raspberry Pi 5')
axes[1].set_xlabel('Importance')
axes[1].set_ylabel('Feature')

save_figure('06_feature_importance.png')
plt.show()
# Out:
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\04_actual_vs_predicted.png
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\05_residual_distributions.png
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\06_feature_importance.png

# %% [markdown]
# ## Train fallback model và xuất artifacts
#
# Ngoài 2 model riêng theo thiết bị, notebook cũng train một **fallback unified model** trên cùng bộ feature để tránh lỗi khi hệ thống nhận `device_type` không xác định.
# Fallback này không log-transform target để giữ tương thích với logic fallback hiện tại trong `EnergyPredictorService`.

# %%
def train_unified_fallback(df: pd.DataFrame):
    X = df[FEATURE_COLUMNS]
    y = df['energy_avg_mwh'].values
    scaler = RobustScaler().fit(X)
    model = ExtraTreesRegressor(
        n_estimators=900,
        max_depth=18,
        max_features=0.9,
        min_samples_split=2,
        min_samples_leaf=1,
        bootstrap=False,
        random_state=SEED,
        n_jobs=-1,
    )
    model.fit(scaler.transform(X), y)
    pred = model.predict(scaler.transform(X))
    return {
        'model': model,
        'scaler': scaler,
        'train_metrics': regression_metrics(y, pred),
        'samples': int(len(df)),
    }


fallback_result = train_unified_fallback(combined_df)
print('FALLBACK TRAIN METRICS')
print(json.dumps(fallback_result['train_metrics'], indent=2, ensure_ascii=False))

jetson_scaler = RobustScaler().fit(jetson_df[FEATURE_COLUMNS])
rpi5_scaler = RobustScaler().fit(rpi5_df[FEATURE_COLUMNS])

jetson_energy = jetson_df['energy_avg_mwh'].values
rpi5_energy = rpi5_df['energy_avg_mwh'].values

thresholds = {
    'jetson_nano': {
        'p10': float(np.percentile(jetson_energy, 10)),
        'p25': float(np.percentile(jetson_energy, 25)),
        'p50': float(np.percentile(jetson_energy, 50)),
        'p75': float(np.percentile(jetson_energy, 75)),
        'p90': float(np.percentile(jetson_energy, 90)),
        'recommended_threshold': float(np.percentile(jetson_energy, 25)),
        'unit': 'mWh',
        'interpretation': 'Mô hình dưới P25 thuộc top 25% tiết kiệm năng lượng nhất',
    },
    'raspberry_pi5': {
        'p10': float(np.percentile(rpi5_energy, 10)),
        'p25': float(np.percentile(rpi5_energy, 25)),
        'p50': float(np.percentile(rpi5_energy, 50)),
        'p75': float(np.percentile(rpi5_energy, 75)),
        'p90': float(np.percentile(rpi5_energy, 90)),
        'recommended_threshold': float(np.percentile(rpi5_energy, 25)),
        'unit': 'mWh',
        'interpretation': 'Mô hình dưới P25 thuộc top 25% tiết kiệm năng lượng nhất',
    },
    'methodology': 'Percentile tính từ benchmark thực tế theo từng thiết bị',
    'last_updated': datetime.now(timezone.utc).isoformat(),
}

metadata = {
    'training_date': datetime.now(timezone.utc).isoformat(),
    'approach': 'device_specific_extra_trees_v2',
    'random_seed': SEED,
    'feature_count': len(FEATURE_COLUMNS),
    'feature_columns': FEATURE_COLUMNS,
    'jetson_batch_threshold_mwh_per_s': JETSON_BATCH_THRESHOLD,
    'jetson_model': {
        'model_type': type(jetson_result['best_estimator']).__name__,
        'model_name': 'Extra Trees + log1p target',
        'n_samples_total': jetson_result['samples'],
        'features': FEATURE_COLUMNS,
        'metrics': {
            'cv_smape': jetson_result['cv_metrics']['smape'],
            'cv_mape_eps': jetson_result['cv_metrics']['mape_eps'],
            'cv_r2': jetson_result['cv_metrics']['r2_log'],
            'cv_r2_original': jetson_result['cv_metrics']['r2_original'],
            'cv_mae': jetson_result['cv_metrics']['mae'],
            'cv_rmse': jetson_result['cv_metrics']['rmse'],
            'cv_median_abs_error': jetson_result['cv_metrics']['median_abs_error'],
        },
        'log_transform_target': False,
        'inference_note': 'Pipeline đã trả về mWh ở original scale; không cần expm1 thêm trong runtime',
        'device_type': 'jetson_nano_2gb',
        'cv_strategy': jetson_result['cv_strategy'],
        'best_params': {k: (v.item() if hasattr(v, 'item') else v) for k, v in jetson_result['best_params'].items()},
    },
    'rpi5_model': {
        'model_type': type(rpi5_result['best_estimator']).__name__,
        'model_name': 'Extra Trees + log1p target',
        'n_samples_total': rpi5_result['samples'],
        'features': FEATURE_COLUMNS,
        'metrics': {
            'cv_smape': rpi5_result['cv_metrics']['smape'],
            'cv_mape_eps': rpi5_result['cv_metrics']['mape_eps'],
            'cv_r2': rpi5_result['cv_metrics']['r2_log'],
            'cv_r2_original': rpi5_result['cv_metrics']['r2_original'],
            'cv_mae': rpi5_result['cv_metrics']['mae'],
            'cv_rmse': rpi5_result['cv_metrics']['rmse'],
            'cv_median_abs_error': rpi5_result['cv_metrics']['median_abs_error'],
        },
        'log_transform_target': False,
        'inference_note': 'Pipeline đã trả về mWh ở original scale; không cần expm1 thêm trong runtime',
        'device_type': 'raspberry_pi_5',
        'cv_strategy': rpi5_result['cv_strategy'],
        'best_params': {k: (v.item() if hasattr(v, 'item') else v) for k, v in rpi5_result['best_params'].items()},
    },
    'fallback_unified_model': {
        'model_type': type(fallback_result['model']).__name__,
        'model_name': 'Extra Trees fallback (no target log transform)',
        'n_samples_total': fallback_result['samples'],
        'features': FEATURE_COLUMNS,
        'train_metrics': fallback_result['train_metrics'],
        'log_transform_target': False,
    },
    'deployment_guide': {
        'routing_logic': "'jetson'/'nano' -> jetson_model; 'raspberry'/'rpi'/'pi' -> rpi5_model; còn lại -> fallback unified model",
        'feature_engineering': 'Tính từ params, gflops, gmacs, size, latency, throughput và các đặc trưng suy diễn',
        'scaling': 'Device models lưu dưới dạng Pipeline nên service dùng trực tiếp model.predict(features_df)',
        'fallback': 'Fallback unified model dùng feature set giống device-specific để tránh mismatch khi unknown device',
    },
}

artifacts = {
    ARTIFACTS_DIR / 'jetson_energy_model.pkl': jetson_result['best_estimator'],
    ARTIFACTS_DIR / 'jetson_scaler.pkl': jetson_scaler,
    ARTIFACTS_DIR / 'rpi5_energy_model.pkl': rpi5_result['best_estimator'],
    ARTIFACTS_DIR / 'rpi5_scaler.pkl': rpi5_scaler,
    ARTIFACTS_DIR / 'energy_predictor.pkl': fallback_result['model'],
    ARTIFACTS_DIR / 'energy_scaler.pkl': fallback_result['scaler'],
}

for path, obj in artifacts.items():
    with open(path, 'wb') as f:
        pickle.dump(obj, f)

with open(ARTIFACTS_DIR / 'feature_names.pkl', 'wb') as f:
    pickle.dump(FEATURE_COLUMNS, f)

with open(ARTIFACTS_DIR / 'device_specific_features.json', 'w', encoding='utf-8') as f:
    json.dump(FEATURE_COLUMNS, f, indent=2, ensure_ascii=False)

with open(ARTIFACTS_DIR / 'device_specific_metadata.json', 'w', encoding='utf-8') as f:
    json.dump(metadata, f, indent=2, ensure_ascii=False)

with open(ARTIFACTS_DIR / 'energy_thresholds.json', 'w', encoding='utf-8') as f:
    json.dump(thresholds, f, indent=2, ensure_ascii=False)

print('Artifacts exported to', ARTIFACTS_DIR)
print('Jetson CV metrics:', json.dumps(jetson_result['cv_metrics'], ensure_ascii=False))
print('RPi5 CV metrics  :', json.dumps(rpi5_result['cv_metrics'], ensure_ascii=False))
# Out:
# FALLBACK TRAIN METRICS
# {
#   "mae": 0.31466099280062376,
#   "rmse": 0.5921745525442762,
#   "smape": 1.4768002226086678,
#   "mape_eps": 1.509540998117275,
#   "r2_original": 0.9999992713831005,
#   "r2_log": 0.9995763410123284,
#   "median_abs_error": 0.11945985954944405
# }
# Artifacts exported to D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts
# Jetson CV metrics: {"mae": 101.3980050765216, "rmse": 550.3426237890056, "smape": 20.162174854870557, "mape_eps": 21.07900438055829, "r2_original": 0.6148207610533192, "r2_log": 0.9402131459830397, "median_abs_error": 5.904591933326586}
# RPi5 CV metrics  : {"mae": 5.155334557172807, "rmse": 12.075813080749729, "smape": 12.781385187961241, "mape_eps": 12.985576543849806, "r2_original": 0.8895876356747618, "r2_log": 0.9571445116452824, "median_abs_error": 2.7181008260958635}

# %% [markdown]
# ## Trực quan hóa ngưỡng năng lượng phục vụ triển khai
#
# Biểu đồ percentile giúp giải thích tại sao notebook chọn `P25` làm ngưỡng khuyến nghị cho từng thiết bị.

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

for ax, energy, title, color, key in [
    (axes[0], jetson_energy, 'Jetson Nano', '#1f77b4', 'jetson_nano'),
    (axes[1], rpi5_energy, 'Raspberry Pi 5', '#d62728', 'raspberry_pi5'),
]:
    sns.histplot(energy, bins=30, kde=True, color=color, ax=ax)
    ax.axvline(thresholds[key]['p25'], color='green', linestyle='--', linewidth=2, label=f"P25 = {thresholds[key]['p25']:.2f} mWh")
    ax.axvline(thresholds[key]['p50'], color='orange', linestyle='--', linewidth=2, label=f"P50 = {thresholds[key]['p50']:.2f} mWh")
    ax.axvline(thresholds[key]['p75'], color='red', linestyle='--', linewidth=2, label=f"P75 = {thresholds[key]['p75']:.2f} mWh")
    ax.set_title(f'Phân phối năng lượng và percentile - {title}')
    ax.set_xlabel('Năng lượng (mWh)')
    ax.set_ylabel('Số lượng mẫu')
    ax.legend()

save_figure('07_energy_threshold_percentiles.png')
plt.show()
# Out:
# Đã lưu hình: D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\07_energy_threshold_percentiles.png

# %% [markdown]
# ## Smoke test tích hợp
#
# Cell cuối cùng sẽ load lại `EnergyPredictorService` của hệ thống và thử dự đoán 3 tình huống:
# - Jetson,
# - Raspberry Pi 5,
# - unknown device (fallback).

# %%
import sys

PYTHON_DIR = PROJECT_ROOT / 'python'
if str(PYTHON_DIR) not in sys.path:
    sys.path.insert(0, str(PYTHON_DIR))

from energy_predictor_service import EnergyPredictorService

service = EnergyPredictorService(str(ARTIFACTS_DIR))
smoke_payloads = [
    {
        'device_type': 'jetson_nano',
        'params_m': 5.0,
        'gflops': 1.5,
        'gmacs': 0.75,
        'size_mb': 20.0,
        'latency_avg_s': 0.05,
        'throughput_iter_per_s': 20.0,
        'power_mode': 'MAXN',
        'name': 'jetson_smoke',
    },
    {
        'device_type': 'raspberry_pi5',
        'params_m': 5.0,
        'gflops': 1.5,
        'gmacs': 0.75,
        'size_mb': 20.0,
        'latency_avg_s': 0.05,
        'throughput_iter_per_s': 20.0,
        'name': 'rpi5_smoke',
    },
    {
        'device_type': 'unknown_edge_device',
        'params_m': 5.0,
        'gflops': 1.5,
        'gmacs': 0.75,
        'size_mb': 20.0,
        'latency_avg_s': 0.05,
        'throughput_iter_per_s': 20.0,
        'name': 'fallback_smoke',
    },
]

smoke_result = service.predict(smoke_payloads)
print(json.dumps(smoke_result, indent=2, ensure_ascii=False))
print()
print('Notebook training pipeline hoàn tất và sẵn sàng tích hợp.')
# Out:
# [
#   {
#     "model_name": "jetson_smoke",
#     "device_type": "jetson_nano",
#     "prediction_mwh": 29.650768499152168,
#     "ci_lower_mwh": 23.400681708346685,
#     "ci_upper_mwh": 35.900855289957654,
#     "model_used": "Extra Trees + log1p target",
#     "mape_pct": 21.07900438055829,
#     "features_used": {
#       "params_m": 5.0,
#       "gflops": 1.5,
#       "gmacs": 0.75,
#       "size_mb": 20.0,
#       "latency_avg_s": 0.05,
#       "throughput_iter_per_s": 20.0,
#       "gflops_per_param": 0.299999940000012,
#       "gmacs_per_mb": 0.03749999812500009,
#       "latency_throughput_ratio": 1.0,
#       "compute_intensity": 0.07500000000000001,
#       "model_complexity": 7.5,
#       "computational_density": 0.07499999625000019,
#       "log_params_m": 1.791759469228055,
#       "log_gflops": 0.9162907318741551,
#       "log_size_mb": 3.044522437723423,
#       "log_gmacs": 0.5596157879354227,
#       "log_latency": 0.048790164169432,
# ...

# %% [markdown]
# ## Danh sách hình đã xuất
#
# Cell này in ra toàn bộ file ảnh PNG đã được lưu vào `ml-controller/artifacts/report_figures` để bạn chèn trực tiếp vào báo cáo.

# %%
figure_files = sorted(FIGURES_DIR.glob('*.png'))
print('Các file hình đã xuất:')
for fig_path in figure_files:
    print('-', fig_path)
# Out:
# Các file hình đã xuất:
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\01_dataset_overview.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\02_jetson_power_profiles.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\03_baseline_model_comparison.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\04_actual_vs_predicted.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\05_residual_distributions.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\06_feature_importance.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\07_energy_threshold_percentiles.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\08_family_distribution.png
# - D:\KLTN\DACN_Energy_consumption\ml-controller\artifacts\report_figures\09_family_energy_patterns.png

# %% [markdown]
# ## Paper-ready Experiment Analysis
#
# Ph?n n?y b? sung pipeline ph?n t?ch th?c nghi?m ph?c v? paper m? **kh?ng thay th?** c?c cell train energy predictor ? ph?a tr?n.
# Notebook s? bootstrap `results/raw/experiment_log.csv` t? d? li?u hi?n c?, chu?n h?a schema, t?nh th?ng k? m? t?, v? sinh to?n b? figure / b?ng / report v?o th? m?c `results/`.

# %%
from pathlib import Path
import sys

def resolve_ml_controller_root() -> Path:
    if "PROJECT_ROOT" in globals():
        return Path(PROJECT_ROOT).resolve()
    cwd = Path.cwd().resolve()
    if (cwd / "python").exists() and (cwd / "data").exists():
        return cwd
    candidate = cwd / "ml-controller"
    if (candidate / "python").exists() and (candidate / "data").exists():
        return candidate.resolve()
    raise FileNotFoundError("Cannot resolve ml-controller root for paper analysis section.")

ML_CONTROLLER_ROOT = resolve_ml_controller_root()
REPO_ROOT = ML_CONTROLLER_ROOT.parent
PYTHON_DIR = ML_CONTROLLER_ROOT / "python"
if str(PYTHON_DIR) not in sys.path:
    sys.path.insert(0, str(PYTHON_DIR))

from energy_predictor_service import EnergyPredictorService
from experiment_logger import DEFAULT_EXPERIMENT_LOG_PATH, ExperimentLogger
from paper_analysis import (
    build_descriptive_stats,
    compute_prediction_metrics,
    compute_summary,
    generate_paper_outputs,
    load_experiment_data,
)

print("ML_CONTROLLER_ROOT =", ML_CONTROLLER_ROOT)
print("REPO_ROOT =", REPO_ROOT)
print("DEFAULT_EXPERIMENT_LOG_PATH =", DEFAULT_EXPERIMENT_LOG_PATH)
# Out:
# ML_CONTROLLER_ROOT = D:\KLTN\DACN_Energy_consumption\ml-controller
# REPO_ROOT = D:\KLTN\DACN_Energy_consumption
# DEFAULT_EXPERIMENT_LOG_PATH = D:\KLTN\DACN_Energy_consumption\results\raw\experiment_log.csv

# %%
predictor = EnergyPredictorService(str(ML_CONTROLLER_ROOT / "artifacts"))
experiment_logger = ExperimentLogger(DEFAULT_EXPERIMENT_LOG_PATH)
experiment_logger.bootstrap_from_existing_sources(
    predictor=lambda payload: predictor.predict([payload])[0].get("prediction_mwh")
)
experiment_df = load_experiment_data(DEFAULT_EXPERIMENT_LOG_PATH)
print(f"Bootstrapped rows: {len(experiment_df)}")
experiment_df.head()
# Out:
# Bootstrapped rows: 629
#       experiment_run_id                 timestamp           scenario  \
# 0  run_b466f941c6579516 2026-01-01 00:00:00+00:00  benchmark_archive
# 1  run_192d6d17886b9ef7 2026-01-01 00:01:00+00:00  benchmark_archive
# 2  run_622f9c88a2720a92 2026-01-01 00:02:00+00:00  benchmark_archive
# 3  run_6ac174d21d554ccc 2026-01-01 00:03:00+00:00  benchmark_archive
# 4  run_0082a9b050f88e67 2026-01-01 00:04:00+00:00  benchmark_archive
#
#   deployment_mode       event_source  device_name device_id device_ip  \
# 0          static  benchmark_archive  Jetson Nano       NaN       NaN
# 1          static  benchmark_archive  Jetson Nano       NaN       NaN
# 2          static  benchmark_archive  Jetson Nano       NaN       NaN
# 3          static  benchmark_archive  Jetson Nano       NaN       NaN
# 4          static  benchmark_archive  Jetson Nano       NaN       NaN
#
#    device_type                   model_name  ... temperature accuracy  \
# ...

# %% [markdown]
# ### Standardized Experiment Schema
#
# C?c c?t d??i ??y l? schema chu?n ph?c v? paper, b?m s?t y?u c?u th?c nghi?m: model metadata, latency, energy, predicted energy, resource telemetry v? deployment mode.

# %%
required_columns = [
    "model_name",
    "model_size_mb",
    "input_resolution",
    "latency_ms",
    "energy_mwh",
    "predicted_energy_mwh",
    "cpu_usage",
    "ram_usage",
    "temperature",
    "accuracy",
    "deployment_mode",
]
experiment_df[required_columns].head(10)
# Out:
#                     model_name  model_size_mb input_resolution    latency_ms  \
# 0             adv_inception_v3          91.24          224x224  9.035155e+04
# 1        beit_base_patch16_224         333.75          224x224  2.961037e+02
# 2  beit_base_patch16_224_in22k         333.71          224x224  3.945150e+05
# 3               cait_xxs24_224          45.77          224x224  1.428850e+05
# 4               cait_xxs24_384          46.05          384x384  8.963265e+05
# 5               cait_xxs36_224          66.22          224x224  2.137253e+05
# 6               cait_xxs36_384          66.50          384x384  1.343178e+06
# 7               coat_lite_mini          42.07          224x224  1.933234e+04
# 8              coat_lite_small          75.79          224x224  3.420433e+04
# 9               coat_lite_tiny          21.93          224x224  8.874994e+01
#
#     energy_mwh  predicted_energy_mwh  cpu_usage  ram_usage  temperature  \
# ...

# %%
summary_df = compute_summary(experiment_df)
descriptive_df = build_descriptive_stats(experiment_df)
prediction_metrics_df = compute_prediction_metrics(experiment_df)

display(summary_df)
display(descriptive_df)
display(prediction_metrics_df)
# Out:
#              scope        group  samples  mean_latency_ms  mean_energy_mwh  \
# 0          overall          all      629     38877.437178       205.146175
# 1           device          CPU      259     40220.933394        43.944341
# 2           device  Jetson Nano      370     37936.989828       318.909868
# 3  deployment_mode     adaptive        6      2710.012833         3.616157
# 4  deployment_mode       static      623     39225.759082       207.096466
#
#    accuracy_samples  mean_accuracy
# 0                 1           60.0
# 1                 0            NaN
# 2                 1           60.0
# 3                 0            NaN
# 4                 1           60.0
#                  metric          mean           std        min           max
# 0            latency_ms  38877.437178  90037.672516  24.023000  1.343178e+06
# 1            energy_mwh    205.146175    687.523802   2.391417  1.173641e+04
# ...

# %% [markdown]
# ### Generate Figures, Tables, and Report
#
# Cell cu?i s? sinh to?n b? output paper-ready v?o `results/`: figure PNG/SVG 300 dpi, b?ng CSV, b?ng LaTeX, pseudo-code v? `report.md`.

# %%
paper_outputs = generate_paper_outputs(DEFAULT_EXPERIMENT_LOG_PATH)
print("Report:", paper_outputs["report_path"])
print("Algorithms:", paper_outputs["algorithms_path"])
print("Summary CSV:", paper_outputs["summary_path"])
print("Figures generated:")
for name, paths in paper_outputs["figure_paths"].items():
    print(f"- {name}: {paths[0]}")
# Out:
# Report: D:\KLTN\DACN_Energy_consumption\results\reports\report.md
# Algorithms: D:\KLTN\DACN_Energy_consumption\results\reports\algorithms.md
# Summary CSV: D:\KLTN\DACN_Energy_consumption\results\processed\summary.csv
# Figures generated:
# - energy_per_model: D:\KLTN\DACN_Energy_consumption\results\figures\energy_per_model.png
# - latency_per_model: D:\KLTN\DACN_Energy_consumption\results\figures\latency_per_model.png
# - accuracy_vs_energy: D:\KLTN\DACN_Energy_consumption\results\figures\accuracy_vs_energy.png
# - predicted_vs_actual_energy: D:\KLTN\DACN_Energy_consumption\results\figures\predicted_vs_actual_energy.png
# - deployment_mode_comparison: D:\KLTN\DACN_Energy_consumption\results\figures\deployment_mode_comparison.png
# - cpu_usage_over_time: D:\KLTN\DACN_Energy_consumption\results\figures\cpu_usage_over_time.png
# - model_family_distribution: D:\KLTN\DACN_Energy_consumption\results\figures\model_family_distribution.png
# ...
